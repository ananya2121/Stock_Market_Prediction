# %%
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# Importing necessary libraries for stock data
from nsepy import get_history
from datetime import date

# Read the data from CSV file
df = pd.read_csv('ICICIBANK.csv')

# Create a new dataframe with only the 'Close' column
data = df.filter(['Close'])

# Converting the dataframe to a numpy array
dataset = data.values

# Get the number of rows to train the model on
training_data_len = math.ceil(len(dataset) * .75)

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# Create the scaled training data set
train_data = scaled_data[0:training_data_len, :]

# Split the data into x_train and y_train data sets
x_train = []
y_train = []
for i in range(30, len(train_data)):
    x_train.append(train_data[i-30:i, 0])
    y_train.append(train_data[i, 0])

# Convert x_train and y_train to numpy arrays
x_train, y_train = np.array(x_train), np.array(y_train)

# Build the MLP model
model = Sequential([
    Dense(50, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(50, activation='relu'),
    Dense(25, activation='relu'),
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, batch_size=50, epochs=100)

# Test data set
test_data = scaled_data[training_data_len - 30:, :]

# Create the x_test data set
x_test = []
for i in range(30, len(test_data)):
    x_test.append(test_data[i-30:i, 0])

# Convert x_test to a numpy array
x_test = np.array(x_test)

# Get the models predicted price values
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)  # Undo scaling

# Calculate RMSE
rmse = np.sqrt(np.mean(((predictions - dataset[training_data_len:, 0]) ** 2)))
print("Root Mean Squared Error:", rmse)

# Plot the predicted values against the actual values
plt.figure(figsize=(14, 7))
plt.plot(dataset[training_data_len:], label='Actual')
plt.plot(predictions, label='Predicted')
plt.title('MLP Predicted vs Actual Values')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 41/41 [==============================] - 3s 4ms/step - loss: 0.0261
# Epoch 2/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0036
# Epoch 3/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 4/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 5/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 6/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 7/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 8/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 9/100
# 41/41 [==============================] - 0s 4ms/step - loss: 9.7071e-04
# Epoch 10/100
# 41/41 [==============================] - 0s 4ms/step - loss: 8.6038e-04
# Epoch 11/100
# 41/41 [==============================] - 0s 4ms/step - loss: 8.3475e-04
# Epoch 12/100
# 41/41 [==============================] - 0s 4ms/step - loss: 9.5398e-04
# Epoch 13/100
# 41/41 [==============================] - 0s 4ms/step - loss: 8.3677e-04
# Epoch 14/100
# 41/41 [==============================] - 0s 4ms/step - loss: 8.1874e-04
# Epoch 15/100
# 41/41 [==============================] - 0s 4ms/step - loss: 7.7892e-04
# Epoch 16/100
# 41/41 [==============================] - 0s 4ms/step - loss: 7.1572e-04
# Epoch 17/100
# 41/41 [==============================] - 0s 4ms/step - loss: 7.3068e-04
# Epoch 18/100
# 41/41 [==============================] - 0s 4ms/step - loss: 7.3946e-04
# Epoch 19/100
# 41/41 [==============================] - 0s 4ms/step - loss: 7.3555e-04
# Epoch 20/100
# 41/41 [==============================] - 0s 4ms/step - loss: 7.5356e-04
# Epoch 21/100
# 41/41 [==============================] - 0s 4ms/step - loss: 7.0792e-04
# Epoch 22/100
# 41/41 [==============================] - 0s 4ms/step - loss: 6.9820e-04
# Epoch 23/100
# 41/41 [==============================] - 0s 4ms/step - loss: 6.7145e-04
# Epoch 24/100
# 41/41 [==============================] - 0s 4ms/step - loss: 7.8743e-04
# Epoch 25/100
# 41/41 [==============================] - 0s 4ms/step - loss: 7.2457e-04
# Epoch 26/100
# 41/41 [==============================] - 0s 4ms/step - loss: 6.9154e-04
# Epoch 27/100
# 41/41 [==============================] - 0s 4ms/step - loss: 6.2875e-04
# Epoch 28/100
# 41/41 [==============================] - 0s 4ms/step - loss: 7.1879e-04
# Epoch 29/100
# 41/41 [==============================] - 0s 4ms/step - loss: 6.7616e-04
# Epoch 30/100
# 41/41 [==============================] - 0s 4ms/step - loss: 6.0920e-04
# Epoch 31/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.2883e-04
# Epoch 32/100
# 41/41 [==============================] - 0s 3ms/step - loss: 7.3168e-04
# Epoch 33/100
# 41/41 [==============================] - 0s 3ms/step - loss: 7.0389e-04
# Epoch 34/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.9452e-04
# Epoch 35/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.5805e-04
# Epoch 36/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.6061e-04
# Epoch 37/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.3857e-04
# Epoch 38/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.9626e-04
# Epoch 39/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.2965e-04
# Epoch 40/100
# 41/41 [==============================] - 0s 3ms/step - loss: 7.1970e-04
# Epoch 41/100
# 41/41 [==============================] - 0s 3ms/step - loss: 7.1831e-04
# Epoch 42/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.4571e-04
# Epoch 43/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.7662e-04
# Epoch 44/100
# 41/41 [==============================] - 0s 3ms/step - loss: 8.9617e-04
# Epoch 45/100
# 41/41 [==============================] - 0s 3ms/step - loss: 7.3863e-04
# Epoch 46/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.3668e-04
# Epoch 47/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.2960e-04
# Epoch 48/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.7651e-04
# Epoch 49/100
# 41/41 [==============================] - 0s 3ms/step - loss: 7.0811e-04
# Epoch 50/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.7014e-04
# Epoch 51/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.8133e-04
# Epoch 52/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.7638e-04
# Epoch 53/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.7602e-04
# Epoch 54/100
# 41/41 [==============================] - 0s 3ms/step - loss: 7.6732e-04
# Epoch 55/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.9238e-04
# Epoch 56/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.2159e-04
# Epoch 57/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.2621e-04
# Epoch 58/100
# 41/41 [==============================] - 0s 4ms/step - loss: 7.1875e-04
# Epoch 59/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.1645e-04
# Epoch 60/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.9495e-04
# Epoch 61/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.7294e-04
# Epoch 62/100
# 41/41 [==============================] - 0s 3ms/step - loss: 7.3595e-04
# Epoch 63/100
# 41/41 [==============================] - 0s 3ms/step - loss: 7.1710e-04
# Epoch 64/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.4635e-04
# Epoch 65/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.9285e-04
# Epoch 66/100
# 41/41 [==============================] - 0s 3ms/step - loss: 7.3287e-04
# Epoch 67/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.3944e-04
# Epoch 68/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.7628e-04
# Epoch 69/100
# 41/41 [==============================] - 0s 3ms/step - loss: 7.3555e-04
# Epoch 70/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.6243e-04
# Epoch 71/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.3238e-04
# Epoch 72/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.1967e-04
# Epoch 73/100
# 41/41 [==============================] - 0s 3ms/step - loss: 7.1736e-04
# Epoch 74/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.7542e-04
# Epoch 75/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.1696e-04
# Epoch 76/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.7068e-04
# Epoch 77/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.4961e-04
# Epoch 78/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.5381e-04
# Epoch 79/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.8957e-04
# Epoch 80/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.9566e-04
# Epoch 81/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.8983e-04
# Epoch 82/100
# 41/41 [==============================] - 0s 3ms/step - loss: 8.5071e-04
# Epoch 83/100
# 41/41 [==============================] - 0s 3ms/step - loss: 7.0442e-04
# Epoch 84/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.1299e-04
# Epoch 85/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.0349e-04
# Epoch 86/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.8255e-04
# Epoch 87/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.1950e-04
# Epoch 88/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.3155e-04
# Epoch 89/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.8347e-04
# Epoch 90/100
# 41/41 [==============================] - 0s 3ms/step - loss: 7.4244e-04
# Epoch 91/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.4050e-04
# Epoch 92/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.1161e-04
# Epoch 93/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.0648e-04
# Epoch 94/100
# 41/41 [==============================] - 0s 3ms/step - loss: 8.0540e-04
# Epoch 95/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.0206e-04
# Epoch 96/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.9581e-04
# Epoch 97/100
# 41/41 [==============================] - 0s 3ms/step - loss: 5.8810e-04
# Epoch 98/100
# 41/41 [==============================] - 0s 3ms/step - loss: 7.7926e-04
# Epoch 99/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.7007e-04
# Epoch 100/100
# 41/41 [==============================] - 0s 3ms/step - loss: 6.5512e-04
# 22/22 [==============================] - 0s 2ms/step
# Root Mean Squared Error: 95.14165230314468
