# %%
# Importing necessary libraries
import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('ICICIBANK.csv')

# Create a new dataframe with only the 'Close' column
data = df.filter(['Close'])

# Convert the dataframe to a numpy array
dataset = data.values

# Scale the data to be values between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1)) 
scaled_data = scaler.fit_transform(dataset)

# Define the training data length
training_data_len = math.ceil(len(dataset) * 0.75)

# Split the data into training and testing sets
train_data = scaled_data[0:training_data_len, :]
test_data = scaled_data[training_data_len - 30:, :]

# Split the data into x_train and y_train data sets
x_train = []
y_train = []
for i in range(30, len(train_data)):
    x_train.append(train_data[i-30:i, 0])
    y_train.append(train_data[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# Define the ANN model
ann_model = Sequential()

# Add the first dense layer
ann_model.add(Dense(units=50, activation='relu', input_dim=x_train.shape[1]))

# Add the second dense layer
ann_model.add(Dense(units=50, activation='relu'))

# Add the output layer
ann_model.add(Dense(units=1))

# Compile the model
ann_model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = ann_model.fit(x_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

# Reshape the test data
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(30, len(test_data)):
    x_test.append(test_data[i-30:i, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1]))

# Predictions
ann_predictions = ann_model.predict(x_test)

# Rescale predictions
ann_predictions = scaler.inverse_transform(ann_predictions)

# Calculate RMSE
ann_rmse = np.sqrt(np.mean((ann_predictions - y_test)**2))

# Plot the predicted values against the original values
plt.figure(figsize=(14, 7))
plt.plot(y_test, label='Original')
plt.plot(ann_predictions, label='Predicted')
plt.title('ANN Predictions vs Original Values')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

print("RMSE:", ann_rmse)
# Out:
# Epoch 1/50
# 57/57 [==============================] - 2s 10ms/step - loss: 0.0231 - val_loss: 4.8156e-04
# Epoch 2/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 6.9010e-05
# Epoch 3/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 2.8237e-05
# Epoch 4/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 3.4758e-05
# Epoch 5/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 2.7836e-05
# Epoch 6/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 2.8516e-05
# Epoch 7/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 5.4591e-05
# Epoch 8/50
# 57/57 [==============================] - 0s 5ms/step - loss: 9.1868e-04 - val_loss: 7.0770e-05
# Epoch 9/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 4.0415e-05
# Epoch 10/50
# 57/57 [==============================] - 0s 5ms/step - loss: 9.4677e-04 - val_loss: 3.1139e-05
# Epoch 11/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 1.8838e-05
# Epoch 12/50
# 57/57 [==============================] - 0s 5ms/step - loss: 9.0347e-04 - val_loss: 1.9411e-05
# Epoch 13/50
# 57/57 [==============================] - 0s 5ms/step - loss: 9.1197e-04 - val_loss: 2.2991e-05
# Epoch 14/50
# 57/57 [==============================] - 0s 5ms/step - loss: 9.0537e-04 - val_loss: 3.1820e-05
# Epoch 15/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.9674e-04 - val_loss: 2.5892e-05
# Epoch 16/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.2644e-04 - val_loss: 2.6075e-05
# Epoch 17/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.9236e-04 - val_loss: 2.0151e-05
# Epoch 18/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.3911e-04 - val_loss: 2.7648e-05
# Epoch 19/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.1845e-04 - val_loss: 7.0751e-05
# Epoch 20/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 2.0418e-05
# Epoch 21/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.7347e-04 - val_loss: 3.7464e-05
# Epoch 22/50
# 57/57 [==============================] - 0s 5ms/step - loss: 9.2062e-04 - val_loss: 1.8000e-05
# Epoch 23/50
# 57/57 [==============================] - 0s 5ms/step - loss: 7.9044e-04 - val_loss: 1.8813e-05
# Epoch 24/50
# 57/57 [==============================] - 0s 5ms/step - loss: 7.6823e-04 - val_loss: 1.7340e-05
# Epoch 25/50
# 57/57 [==============================] - 0s 5ms/step - loss: 7.4679e-04 - val_loss: 2.5968e-05
# Epoch 26/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.6256e-04 - val_loss: 1.8107e-05
# Epoch 27/50
# 57/57 [==============================] - 0s 5ms/step - loss: 9.4167e-04 - val_loss: 3.0133e-05
# Epoch 28/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.1555e-04 - val_loss: 4.2293e-05
# Epoch 29/50
# 57/57 [==============================] - 0s 5ms/step - loss: 7.7269e-04 - val_loss: 1.5776e-05
# Epoch 30/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.7483e-04 - val_loss: 2.6011e-05
# Epoch 31/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.1054e-04 - val_loss: 2.5764e-05
# Epoch 32/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.4170e-04 - val_loss: 1.6534e-05
# Epoch 33/50
# 57/57 [==============================] - 0s 5ms/step - loss: 7.8908e-04 - val_loss: 2.1137e-05
# Epoch 34/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.5095e-04 - val_loss: 1.6054e-05
# Epoch 35/50
# 57/57 [==============================] - 0s 5ms/step - loss: 7.7644e-04 - val_loss: 1.8620e-05
# Epoch 36/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.6341e-04 - val_loss: 1.8845e-05
# Epoch 37/50
# 57/57 [==============================] - 0s 5ms/step - loss: 7.5641e-04 - val_loss: 9.8783e-05
# Epoch 38/50
# 57/57 [==============================] - 0s 5ms/step - loss: 7.9650e-04 - val_loss: 1.5824e-05
# Epoch 39/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.1222e-04 - val_loss: 1.5988e-05
# Epoch 40/50
# 57/57 [==============================] - 0s 6ms/step - loss: 8.4397e-04 - val_loss: 1.7986e-05
# Epoch 41/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.2987e-04 - val_loss: 1.6797e-05
# Epoch 42/50
# 57/57 [==============================] - 0s 5ms/step - loss: 8.0457e-04 - val_loss: 1.9387e-05
# Epoch 43/50
# 57/57 [==============================] - 0s 6ms/step - loss: 8.4518e-04 - val_loss: 1.6291e-05
# Epoch 44/50
# 57/57 [==============================] - 0s 7ms/step - loss: 8.4209e-04 - val_loss: 1.5137e-05
# Epoch 45/50
# 57/57 [==============================] - 0s 7ms/step - loss: 7.6737e-04 - val_loss: 1.9621e-05
# Epoch 46/50
# 57/57 [==============================] - 0s 6ms/step - loss: 7.6348e-04 - val_loss: 1.8730e-05
# Epoch 47/50
# 57/57 [==============================] - 0s 6ms/step - loss: 7.7074e-04 - val_loss: 1.4578e-05
# Epoch 48/50
# 57/57 [==============================] - 0s 5ms/step - loss: 7.3616e-04 - val_loss: 1.9632e-05
# Epoch 49/50
# 57/57 [==============================] - 0s 5ms/step - loss: 7.2038e-04 - val_loss: 1.7276e-05
# Epoch 50/50
# 57/57 [==============================] - 0s 5ms/step - loss: 9.1539e-04 - val_loss: 1.5416e-05
# 22/22 [==============================] - 0s 3ms/step
# RMSE: 7.9432449209852845
